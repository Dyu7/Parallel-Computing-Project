# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
import numpy as np

# %%
#MNIST dataset
#gpu data points
mnist_data_points_gpu = []
data_point_1 = {'Number_of_Samples':50,'Iterations':100,'Accuracy':0.42,'Execution Time':3.749}
mnist_data_points_gpu.append(data_point_1)
data_point_2 = {'Number_of_Samples':50,'Iterations':1000,'Accuracy':0.92,'Execution Time':12.483}
mnist_data_points_gpu.append(data_point_2)
data_point_3 = {'Number_of_Samples':100,'Iterations':1000,'Accuracy':0.89,'Execution Time':17.526}
mnist_data_points_gpu.append(data_point_3)
data_point_4 = {'Number_of_Samples':100,'Iterations':10000,'Accuracy':0.90,'Execution Time':143.580}
mnist_data_points_gpu.append(data_point_4)
data_point_5 = {'Number_of_Samples':200,'Iterations':1000,'Accuracy':0.77,'Execution Time':24.538}
mnist_data_points_gpu.append(data_point_5)
data_point_6 = {'Number_of_Samples':200,'Iterations':10000,'Accuracy':0.90,'Execution Time':225.242}
mnist_data_points_gpu.append(data_point_6)

# %%
#cpu data points
mnist_data_points_cpu = []
data_point_1 = {'Number_of_Samples':50,'Iterations':100,'Accuracy':0.38,'Execution Time':14.543}
mnist_data_points_cpu.append(data_point_1)
data_point_2 = {'Number_of_Samples':50,'Iterations':1000,'Accuracy':0.98,'Execution Time':129.912}
mnist_data_points_cpu.append(data_point_2)
data_point_3 = {'Number_of_Samples':100,'Iterations':1000,'Accuracy':0.81,'Execution Time':246.142}
mnist_data_points_cpu.append(data_point_3)
data_point_4 = {'Number_of_Samples':100,'Iterations':10000,'Accuracy':0.96,'Execution Time':2284.952}
mnist_data_points_cpu.append(data_point_4)
data_point_5 = {'Number_of_Samples':200,'Iterations':1000,'Accuracy':0.73,'Execution Time':512.873}
mnist_data_points_cpu.append(data_point_5)
data_point_6 = {'Number_of_Samples':200,'Iterations':10000,'Accuracy':0.92,'Execution Time':4789.304}
mnist_data_points_cpu.append(data_point_6)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('Number of Samples')
ax.set_ylabel('Iterations')
ax.set_zlabel('Execution Time(s)')
ax.set_title('GPU Execution Times')

X, Y, Z = [],[],[]
for i in mnist_data_points_gpu:
    X.append(i['Number_of_Samples'])
    Y.append(i['Iterations'])
    Z.append(i['Execution Time'])
X = np.array(X)
Y = np.array(Y)
Z = np.array(Z)
ax.plot3D(X, Y, Z)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('Number of Samples')
ax.set_ylabel('Iterations')
ax.set_zlabel('Execution Time(s)')
ax.set_title('CPU Execution Times')

X, Y, Z = [],[],[]
for i in mnist_data_points_cpu:
    X.append(i['Number_of_Samples'])
    Y.append(i['Iterations'])
    Z.append(i['Execution Time'])
X = np.array(X)
Y = np.array(Y)
Z = np.array(Z)
ax.plot3D(X, Y, Z)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('Number of Samples')
ax.set_ylabel('Iterations')
ax.set_zlabel('Speedup')
ax.set_title('GPU Speedup')

X, Y, Z = [],[],[]
for i in range(len(mnist_data_points_cpu)):
    X.append(mnist_data_points_cpu[i]['Number_of_Samples'])
    Y.append(mnist_data_points_cpu[i]['Iterations'])
    Z.append(mnist_data_points_cpu[i]['Execution Time'] / 
             mnist_data_points_gpu[i]['Execution Time']
            )
X = np.array(X)
Y = np.array(Y)
Z = np.array(Z)
ax.plot3D(X, Y, Z)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Number of Samples x Iterations')
ax.set_ylabel('Execution Time(s)')
ax.set_title('GPU Execution Times')

X, Y = [],[]
for i in mnist_data_points_gpu:
    X.append(i['Number_of_Samples']*i['Iterations'])
    Y.append(i['Execution Time'])
#sorting inputs
Y = [y for _,y in sorted(zip(X,Y))]
X = sorted(X)
X = np.array(X)
Y = np.array(Y)
ax.plot(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="729">

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Number of Samples x Iterations')
ax.set_ylabel('Execution Time(s)')
ax.set_title('CPU Execution Times')

X, Y = [],[]
for i in mnist_data_points_cpu:
    X.append(i['Number_of_Samples']*i['Iterations'])
    Y.append(i['Execution Time'])
#sorting inputs
Y = [y for _,y in sorted(zip(X,Y))]
X = sorted(X)
X = np.array(X)
Y = np.array(Y)
ax.plot(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="772">

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Number of Samples x Iterations')
ax.set_ylabel('Execution Time(s)')
ax.set_title('GPU Speedup')

X, Y = [],[]
for i in range(len(mnist_data_points_cpu)):
    X.append(mnist_data_points_cpu[i]['Number_of_Samples']*mnist_data_points_cpu[i]['Iterations'])
    Y.append(mnist_data_points_cpu[i]['Execution Time'] / 
             mnist_data_points_gpu[i]['Execution Time']
            )
#sorting inputs
Y = [y for _,y in sorted(zip(X,Y))]
X = sorted(X)
X = np.array(X)
Y = np.array(Y)
ax.plot(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="781">

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('Number of Samples')
ax.set_ylabel('Iterations')
ax.set_zlabel('Accuracy(%)')
ax.set_title('GPU Accuracy Graph')

X, Y, Z = [],[],[]
for i in mnist_data_points_gpu:
    X.append(i['Number_of_Samples'])
    Y.append(i['Iterations'])
    Z.append(i['Accuracy'])
X = np.array(X)
Y = np.array(Y)
Z = np.array(Z)
ax.plot3D(X, Y, Z)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="643">

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel('Number of Samples')
ax.set_ylabel('Iterations')
ax.set_zlabel('Accuracy(%)')
ax.set_title('CPU Accuracy Graph')

X, Y, Z = [],[],[]
for i in mnist_data_points_cpu:
    X.append(i['Number_of_Samples'])
    Y.append(i['Iterations'])
    Z.append(i['Accuracy'])
X = np.array(X)
Y = np.array(Y)
Z = np.array(Z)
ax.plot3D(X, Y, Z)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Number of Samples x Iterations')
ax.set_ylabel('Execution Time(s)')
ax.set_title('GPU Accuracy Graph')

X, Y = [],[]
for i in mnist_data_points_gpu:
    X.append(i['Number_of_Samples']*i['Iterations'])
    Y.append(i['Accuracy'])
#sorting inputs
Y = [y for _,y in sorted(zip(X,Y))]
X = sorted(X)
X = np.array(X)
Y = np.array(Y)
ax.plot(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="805">

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Number of Samples x Iterations')
ax.set_ylabel('Execution Time(s)')
ax.set_title('CPU Accuracy Graph')

X, Y = [],[]
for i in mnist_data_points_cpu:
    X.append(i['Number_of_Samples']*i['Iterations'])
    Y.append(i['Accuracy'])
#sorting inputs
Y = [y for _,y in sorted(zip(X,Y))]
X = sorted(X)
X = np.array(X)
Y = np.array(Y)
ax.plot(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="811">

# %%
#IRIS Flower Dataset
#gpu data points
iris_data_points_gpu = []
data_point_1 = {'Iterations':1000,'Accuracy':0.72,'Execution Time':2.472}
iris_data_points_gpu.append(data_point_1)
data_point_2 = {'Iterations':2000,'Accuracy':0.87,'Execution Time':4.765}
iris_data_points_gpu.append(data_point_2)
data_point_3 = {'Iterations':3000,'Accuracy':0.92,'Execution Time':7.083}
iris_data_points_gpu.append(data_point_3)
data_point_4 = {'Iterations':4000,'Accuracy':0.93,'Execution Time':9.337}
iris_data_points_gpu.append(data_point_4)
data_point_5 = {'Iterations':5000,'Accuracy':0.92,'Execution Time':11.569}
iris_data_points_gpu.append(data_point_5)
data_point_6 = {'Iterations':6000,'Accuracy':0.93,'Execution Time':14.686}
iris_data_points_gpu.append(data_point_6)
data_point_7 = {'Iterations':7000,'Accuracy':0.95,'Execution Time':16.887}
iris_data_points_gpu.append(data_point_7)
data_point_8 = {'Iterations':8000,'Accuracy':0.94,'Execution Time':19.217}
iris_data_points_gpu.append(data_point_8)
data_point_9 = {'Iterations':9000,'Accuracy':0.97,'Execution Time':22.395}
iris_data_points_gpu.append(data_point_9)
data_point_10 = {'Iterations':10000,'Accuracy':0.98,'Execution Time':24.050}
iris_data_points_gpu.append(data_point_10)

# %%
#cpu data points
iris_data_points_cpu = []
data_point_1 = {'Iterations':1000,'Accuracy':0.67,'Execution Time':4.723}
iris_data_points_cpu.append(data_point_1)
data_point_2 = {'Iterations':2000,'Accuracy':0.73,'Execution Time':8.719}
iris_data_points_cpu.append(data_point_2)
data_point_3 = {'Iterations':3000,'Accuracy':0.82,'Execution Time':13.069}
iris_data_points_cpu.append(data_point_3)
data_point_4 = {'Iterations':4000,'Accuracy':0.85,'Execution Time':17.461}
iris_data_points_cpu.append(data_point_4)
data_point_5 = {'Iterations':5000,'Accuracy':0.90,'Execution Time':21.435}
iris_data_points_cpu.append(data_point_5)
data_point_6 = {'Iterations':6000,'Accuracy':0.96,'Execution Time':25.854}
iris_data_points_cpu.append(data_point_6)
data_point_7 = {'Iterations':7000,'Accuracy':0.94,'Execution Time':30.229}
iris_data_points_cpu.append(data_point_7)
data_point_8 = {'Iterations':8000,'Accuracy':0.96,'Execution Time':34.389}
iris_data_points_cpu.append(data_point_8)
data_point_9 = {'Iterations':9000,'Accuracy':0.96,'Execution Time':38.575}
iris_data_points_cpu.append(data_point_9)
data_point_10 = {'Iterations':10000,'Accuracy':0.97,'Execution Time':43.357}
iris_data_points_cpu.append(data_point_10)

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Iterations')
ax.set_ylabel('Execution Time(s)')
ax.set_title('GPU Execution Times')

X, Y = [],[]
for i in iris_data_points_gpu:
    X.append(i['Iterations'])
    Y.append(i['Execution Time'])
X = np.array(X)
Y = np.array(Y)
ax.plot(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Iterations')
ax.set_ylabel('Execution Time(s)')
ax.set_title('CPU Execution Times')

X, Y = [],[]
for i in iris_data_points_cpu:
    X.append(i['Iterations'])
    Y.append(i['Execution Time'])
X = np.array(X)
Y = np.array(Y)
ax.plot(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Iterations')
ax.set_ylabel('Speedup')
ax.set_title('GPU Speedup')

X, Y = [],[]
for i in range(len(iris_data_points_cpu)):
    X.append(iris_data_points_cpu[i]['Iterations'])
    Y.append(iris_data_points_cpu[i]['Execution Time'] /
             iris_data_points_gpu[i]['Execution Time']
            )
X = np.array(X)
Y = np.array(Y)
ax.plot(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Iterations')
ax.set_ylabel('Accuracy%')
ax.set_title('GPU Accuracy')

X, Y = [],[]
for i in iris_data_points_gpu:
    X.append(i['Iterations'])
    Y.append(i['Accuracy']*100)
X = np.array(X)
Y = np.array(Y)
ax.plot(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax = plt.subplots()
ax.set_xlabel('Iterations')
ax.set_ylabel('Accuracy%')
ax.set_title('CPU Accuracy')

X, Y = [],[]
for i in iris_data_points_cpu:
    X.append(i['Iterations'])
    Y.append(i['Accuracy']*100)
X = np.array(X)
Y = np.array(Y)
ax.plot(X, Y)
# Out:
# <img src="data:image/png;base64,..." width="640">
